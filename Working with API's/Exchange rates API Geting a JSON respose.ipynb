# %% [markdown]
# ## Pulling data from public APIs -GET request

# %%
base_url= "https://cdn.jsdelivr.net/gh/fawazahmed0/currency-api@1/latest/currencies/eur.json"

# %% [markdown]
# ## Extracting data on currency exchage rates
#
# ### Sending a GET request

# %%
import requests

# %%
response = requests.get(base_url)

# %% [markdown]
# ## Investing the response

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{\n    "date": "2023-03-05",\n    "eur": {\n        "1inch": 2.038615,\n        "aave": 0.01393,\n        "ada": 3.132466,\n        "aed": 3.911926,\n        "afn": 95.323448,\n        "algo": 4.683787,\n        "all": 115.421474,\n        "amd": 413.40884,\n        "amp": 203.912739,\n        "ang": 1.919921,\n        "aoa": 539.436344,\n        "ar": 0.118283,\n        "ars": 210.844855,\n        "atom": 0.088645,\n        "aud": 1.573406,\n        "avax": 0.065013,\n        "awg": 1.919697,\n        "axs": 0.11961,\n        "azn": 1.81476,\n        "bake": 5.520685,\n        "bam": 1.962924,\n        "bat": 4.050723,\n        "bbd": 2.150974,\n        "bch": 0.008464,\n        "bdt": 113.986575,\n        "bgn": 1.959417,\n        "bhd": 0.400926,\n        "bif": 2213.109403,\n        "bmd": 1.065019,\n        "bnb": 0.003658,\n        "bnd": 1.434003,\n        "bob": 7.361234,\n        "brl": 5.533736,\n        "bsd": 1.06535,\n        "bsv": 0.02741,\n        "bsw": 5.187252,\n 
# ...

# %%
response.content
# Out:
# b'{\n    "date": "2023-03-05",\n    "eur": {\n        "1inch": 2.038615,\n        "aave": 0.01393,\n        "ada": 3.132466,\n        "aed": 3.911926,\n        "afn": 95.323448,\n        "algo": 4.683787,\n        "all": 115.421474,\n        "amd": 413.40884,\n        "amp": 203.912739,\n        "ang": 1.919921,\n        "aoa": 539.436344,\n        "ar": 0.118283,\n        "ars": 210.844855,\n        "atom": 0.088645,\n        "aud": 1.573406,\n        "avax": 0.065013,\n        "awg": 1.919697,\n        "axs": 0.11961,\n        "azn": 1.81476,\n        "bake": 5.520685,\n        "bam": 1.962924,\n        "bat": 4.050723,\n        "bbd": 2.150974,\n        "bch": 0.008464,\n        "bdt": 113.986575,\n        "bgn": 1.959417,\n        "bhd": 0.400926,\n        "bif": 2213.109403,\n        "bmd": 1.065019,\n        "bnb": 0.003658,\n        "bnd": 1.434003,\n        "bob": 7.361234,\n        "brl": 5.533736,\n        "bsd": 1.06535,\n        "bsv": 0.02741,\n        "bsw": 5.187252,\n
# ...

# %% [markdown]
# ## Handling the JSON

# %%
dict(response.json(), index=4)
# Out:
# {'date': '2023-03-05',
#  'eur': {'1inch': 2.038615,
#   'aave': 0.01393,
#   'ada': 3.132466,
#   'aed': 3.911926,
#   'afn': 95.323448,
#   'algo': 4.683787,
#   'all': 115.421474,
#   'amd': 413.40884,
#   'amp': 203.912739,
#   'ang': 1.919921,
#   'aoa': 539.436344,
#   'ar': 0.118283,
#   'ars': 210.844855,
#   'atom': 0.088645,
#   'aud': 1.573406,
#   'avax': 0.065013,
#   'awg': 1.919697,
#   'axs': 0.11961,
#   'azn': 1.81476,
#   'bake': 5.520685,
#   'bam': 1.962924,
#   'bat': 4.050723,
#   'bbd': 2.150974,
#   'bch': 0.008464,
#   'bdt': 113.986575,
#   'bgn': 1.959417,
#   'bhd': 0.400926,
#   'bif': 2213.109403,
#   'bmd': 1.065019,
#   'bnb': 0.003658,
#   'bnd': 1.434003,
#   'bob': 7.361234,
#   'brl': 5.533736,
#   'bsd': 1.06535,
#   'bsv': 0.02741,
#   'bsw': 5.187252,
#   'btc': 4.7e-05,
#   'btcb': 4.7e-05,
#   'btg': 0.065644,
#   'btn': 87.286552,
#   'busd': 1.064547,
#   'bwp': 14.091193,
#   'byn': 2.688918,
#   'byr': 20874.371657,
#   'bzd': 2.147361,
# ...

# %%
import json

# %%
json.dumps(response.json(), indent=10)
# Out:
# '{\n          "date": "2023-03-05",\n          "eur": {\n                    "1inch": 2.038615,\n                    "aave": 0.01393,\n                    "ada": 3.132466,\n                    "aed": 3.911926,\n                    "afn": 95.323448,\n                    "algo": 4.683787,\n                    "all": 115.421474,\n                    "amd": 413.40884,\n                    "amp": 203.912739,\n                    "ang": 1.919921,\n                    "aoa": 539.436344,\n                    "ar": 0.118283,\n                    "ars": 210.844855,\n                    "atom": 0.088645,\n                    "aud": 1.573406,\n                    "avax": 0.065013,\n                    "awg": 1.919697,\n                    "axs": 0.11961,\n                    "azn": 1.81476,\n                    "bake": 5.520685,\n                    "bam": 1.962924,\n                    "bat": 4.050723,\n                    "bbd": 2.150974,\n                    "bch": 0.008464,\n                
# ...

# %%
print (json.dumps(response.json(), indent=10))
# Out:
# {
#           "date": "2023-03-05",
#           "eur": {
#                     "1inch": 2.038615,
#                     "aave": 0.01393,
#                     "ada": 3.132466,
#                     "aed": 3.911926,
#                     "afn": 95.323448,
#                     "algo": 4.683787,
#                     "all": 115.421474,
#                     "amd": 413.40884,
#                     "amp": 203.912739,
#                     "ang": 1.919921,
#                     "aoa": 539.436344,
#                     "ar": 0.118283,
#                     "ars": 210.844855,
#                     "atom": 0.088645,
#                     "aud": 1.573406,
#                     "avax": 0.065013,
#                     "awg": 1.919697,
#                     "axs": 0.11961,
#                     "azn": 1.81476,
#                     "bake": 5.520685,
#                     "bam": 1.962924,
#                     "bat": 4.050723,
#                     "bbd": 2.150974,
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['date', 'eur'])
